# %% [markdown]
# # Create a map of FUA location
#
# Shows all FUAs used in the study on a map to be shown in the paper.

# %%
import os
os.environ['USE_PYGEOS'] = '0'

import geopandas
import geodatasets
import pandas
import numpy
import matplotlib.pyplot as plt
import seaborn as sns
from palettable.cartocolors.qualitative import Bold_6
from matplotlib.lines import Line2D

# %% [markdown]
# Set default plotting theme.

# %%
sns.set_theme(
    context="paper",
    style="ticks",
    rc={
        "patch.force_edgecolor": False,
        "axes.spines.top": False,
        "axes.spines.right": False,
        "axes.grid": True,
    },
    palette=Bold_6.hex_colors,
)

coldict = {
    'Africa': 0, 
    'Asia': 1, 
    'Europe': 2, 
    'North America': 3, 
    'Oceania': 4, 
    'South America': 5,
}

# %% [markdown]
# Load the data with continent land masses. Project to Robinson.

# %%
world = geopandas.read_file(geodatasets.get_path("naturalearth land")).to_crs("ESRI:54030")

# %% [markdown]
# Load FUA samples.

# %%
sample = geopandas.read_parquet("../data/sample.parquet").to_crs("ESRI:54030")

# %% [markdown]
# Use centroid instead of polygons.

# %%
sample = sample.set_geometry(sample.centroid)

# %% [markdown]
# Plot using the color schema set for continents.

# %%
ax = world.plot(facecolor="none", edgecolor='k', figsize=(12, 12))
legend_patches = []
for cont, col in coldict.items():
    sample.query(f"continent == '{cont}'").plot(
        color=Bold_6.hex_colors[col], 
        ax=ax,
        markersize=15,
    )
    legend_patches.append(
        Line2D(
            [0],
            [0],
            linestyle="none",
            marker="o",
            markersize=10,
            markerfacecolor=Bold_6.hex_colors[col],
            markeredgewidth=0,
        )
    )
ax.set_axis_off()
ax.legend(
    labels=coldict.keys(), 
    handles=legend_patches, 
    loc='lower center', 
    ncols=6, 
    frameon=False,
    bbox_to_anchor=(0.5, -.03),
)
for ext in ["png", "svg", "pdf"]:
    plt.savefig(f"../plots/cities/fua_locations.{ext}", dpi=300)
