# %% [markdown]
# # Analyse a sample of FUAs with service roads
#
# This notebook produces face polygons and computes shape metrics for each of them.
#
# Unlike the 02_measure notebook, this does not exclude service roads from the network before polygonization.

# %%
import warnings

import geopandas
import dask_geopandas
import numpy
import pygeos
import esda.shape as shape

from tqdm import tqdm

# %%
sample = geopandas.read_parquet("../data/sample.parquet")

# %% [markdown]
# ## Measure shape characteristics
#
# Polygonize the network to get polygons fully enclosed by street network geometry (face polygons) and measure their shape characteristics.

# %%
# Filter warnings about GeoParquet implementation.
warnings.filterwarnings('ignore', message='.*initial implementation of Parquet.*')

# Loop over unique FUA IDs
for fua_id in tqdm(sample.eFUA_ID, total=len(sample)):
    # Read stret network
    roads = geopandas.read_parquet(f"../data/{int(fua_id)}/roads_osm.parquet")

    # Polygonize street network
    polygons = pygeos.polygonize(roads.geometry.array.data)
    
    # Store geometries as a GeoDataFrame
    polygons = geopandas.GeoDataFrame(
        geometry=geopandas.GeoSeries(
            [polygons], crs=roads.crs
        ).explode(ignore_index=True)
    )
    
    if not polygons.is_valid.all():
        polygons = geopandas.GeoDataFrame(
        geometry=geopandas.GeoSeries(
            pygeos.make_valid(polygons.geometry.values.data), crs=roads.crs
        ).explode(ignore_index=True)
    )

    # Extract underlying PyGEOS geometries pygeos understands (minimum_bounding_circle is not yet exposed in geopandas)
    ga = polygons.geometry.array.data

    # measure area
    polygons["area"] = polygons.area
    # generate minimum bounding circle
    circles = geopandas.GeoDataFrame(
        geometry=geopandas.GeoSeries(pygeos.minimum_bounding_circle(ga), crs=polygons.crs)
    )
    # measure MBC's area
    circles["circle_area"] = circles.area

    # measure Reock (circular) compactness
    polygons["reock"] = polygons["area"] / circles["circle_area"]
  
    # measure direct shape index that captures banana-like relationship between area and Reock compactness in a one dimension
    polygons["shape_index"] = polygons["area"] / numpy.sqrt(circles["circle_area"])
    
    # isoperimetric_quotient
    polygons["isoperimetric_quotient"] = shape.isoperimetric_quotient(polygons)

    # isoareal_quotient
    polygons["isoareal_quotient"] = shape.isoareal_quotient(polygons)

    # radii_ratio
    polygons["radii_ratio"] = shape.radii_ratio(polygons)

    # diameter_ratio
    polygons["diameter_ratio"] = shape.diameter_ratio(polygons)

    # boundary_amplitude
    polygons["boundary_amplitude"] = shape.boundary_amplitude(polygons)

    # squareness
    polygons["squareness"] = shape.squareness(polygons)

    # Schumm's shape_index
    polygons["schumm_shape_index"] = shape.shape_index(polygons)

    # save polygons to a partitioned GeoParquet
    polygons = dask_geopandas.from_geopandas(polygons, npartitions=10)
    polygons.to_parquet(f"../data/{int(fua_id)}/polygons_incl_sr/")
    
    # save circles to a partitioned GeoParquet
    circles = dask_geopandas.from_geopandas(circles, npartitions=10)
    circles.to_parquet(f"../data/{int(fua_id)}/circles_incl_sr/")
# Out:
#   0%|          | 0/131 [00:00<?, ?it/s]/Users/martin/mambaforge/envs/stable/lib/python3.10/site-packages/pygeos/constructive.py:579: RuntimeWarning: invalid value encountered in polygonize
#   return lib.polygonize(geometries, **kwargs)
# /Users/martin/mambaforge/envs/stable/lib/python3.10/site-packages/pygeos/constructive.py:478: RuntimeWarning: invalid value encountered in make_valid
#   return lib.make_valid(geometry, **kwargs)
#   2%|▏         | 2/131 [00:00<00:40,  3.16it/s]/Users/martin/mambaforge/envs/stable/lib/python3.10/site-packages/pygeos/constructive.py:579: RuntimeWarning: invalid value encountered in polygonize
#   return lib.polygonize(geometries, **kwargs)
#   2%|▏         | 3/131 [00:00<00:35,  3.62it/s]/Users/martin/mambaforge/envs/stable/lib/python3.10/site-packages/pygeos/constructive.py:579: RuntimeWarning: invalid value encountered in polygonize
#   return lib.polygonize(geometries, **kwargs)
#   3%|▎         | 4/131 [00:01<00:29,  4.36it/s]/Users/martin/mambaforge/envs/stable/lib/python3.10/site-packages/pygeos/constructive.py:579: RuntimeWarning: invalid value encountered in polygonize
#   return lib.polygonize(geometries, **kwargs)
#   4%|▍         | 5/131 [00:01<00:23,  5.39it/s]/Users/martin/mambaforge/envs/stable/lib/python3.10/site-packages/pygeos/constructive.py:579: RuntimeWarning: invalid value encountered in polygonize
#   return lib.polygonize(geometries, **kwargs)
#   5%|▍         | 6/131 [00:01<00:39,  3.13it/s]/Users/martin/mambaforge/envs/stable/lib/python3.10/site-packages/pygeos/constructive.py:579: RuntimeWarning: invalid value encountered in polygonize
#   return lib.polygonize(geometries, **kwargs)
#   5%|▌         | 7/131 [00:02<00:48,  2.58it/s]/Users/martin/mambaforge/envs/stable/lib/python3.10/site-packages/pygeos/constructive.py:579: RuntimeWarning: invalid value encountered in polygonize
#   return lib.polygonize(geometries, **kwargs)
#   6%|▌         | 8/131 [00:02<00:50,  2.44it/s]/Users/martin/mambaforge/envs/stable/lib/python3.10/site-packages/pygeos/constructive.py:579: RuntimeWarning: invalid value encountered in polygonize
#   return lib.polygonize(geometries, **kwargs)
#   7%|▋         | 9/131 [00:03<01:16,  1.60it/s]/Users/martin/mambaforge/envs/stable/lib/python3.10/site-packages/pygeos/constructive.py:579: RuntimeWarning: invalid value encountered in polygonize
#   return lib.polygonize(geometries, **kwargs)
#   8%|▊         | 10/131 [00:03<00:57,  2.09it/s]/Users/martin/mambaforge/envs/stable/lib/python3.10/site-packages/pygeos/constructive.py:579: RuntimeWarning: invalid value encountered in polygonize
#   return lib.polygonize(geometries, **kwargs)
#   8%|▊         | 11/131 [00:04<00:56,  2.13it/s]/Users/martin/mambaforge/envs/stable/lib/python3.10/site-packages/pygeos/constructive.py:579: RuntimeWarning: invalid value encountered in polygonize
#   return lib.polygonize(geometries, **kwargs)
#   9%|▉         | 12/131 [00:04<00:42,  2.79it/s]/Users/martin/mambaforge/envs/stable/lib/python3.10/site-packages/pygeos/constructive.py:579: RuntimeWarning: invalid value encountered in polygonize
#   return lib.polygonize(geometries, **kwargs)
#  10%|▉         | 13/131 [00:06<01:50,  1.07it/s]/Users/martin/mambaforge/envs/stable/lib/python3.10/site-packages/pygeos/constructive.py:579: RuntimeWarning: invalid value encountered in polygonize
#   return lib.polygonize(geometries, **kwargs)
#  11%|█         | 14/131 [00:07<01:28,  1.33it/s]/Users/martin/mambaforge/envs/stable/lib/python3.10/site-packages/pygeos/constructive.py:579: RuntimeWarning: invalid value encountered in polygonize
#   return lib.polygonize(geometries, **kwargs)
#  11%|█▏        | 15/131 [00:07<01:11,  1.62it/s]/Users/martin/mambaforge/envs/stable/lib/python3.10/site-packages/pygeos/constructive.py:579: RuntimeWarning: invalid value encountered in polygonize
#   return lib.polygonize(geometries, **kwargs)
#  12%|█▏        | 16/131 [00:08<01:12,  1.59it/s]/Users/martin/mambaforge/envs/stable/lib/python3.10/site-packages/pygeos/constructive.py:579: RuntimeWarning: invalid value encountered in polygonize
#   return lib.polygonize(geometries, **kwargs)
#  13%|█▎        | 17/131 [00:08<01:07,  1.69it/s]/Users/martin/mambaforge/envs/stable/lib/python3.10/site-packages/pygeos/constructive.py:579: RuntimeWarning: invalid value encountered in polygonize
#   return lib.polygonize(geometries, **kwargs)
#  14%|█▎        | 18/131 [00:08<01:01,  1.83it/s]/Users/martin/mambaforge/envs/stable/lib/python3.10/site-packages/pygeos/constructive.py:579: RuntimeWarning: invalid value encountered in polygonize
#   return lib.polygonize(geometries, **kwargs)
# /Users/martin/mambaforge/envs/stable/lib/python3.10/site-packages/pygeos/constructive.py:478: RuntimeWarning: invalid value encountered in make_valid
#   return lib.make_valid(geometry, **kwargs)
#  15%|█▍        | 19/131 [00:13<03:02,  1.63s/it]/Users/martin/mambaforge/envs/stable/lib/python3.10/site-packages/pygeos/constructive.py:579: RuntimeWarning: invalid value encountered in polygonize
#   return lib.polygonize(geometries, **kwargs)
#  16%|█▌        | 21/131 [00:13<01:44,  1.06it/s]/Users/martin/mambaforge/envs/stable/lib/python3.10/site-packages/pygeos/constructive.py:579: RuntimeWarning: invalid value encountered in polygonize
#   return lib.polygonize(geometries, **kwargs)
#  17%|█▋        | 22/131 [00:14<01:23,  1.30it/s]/Users/martin/mambaforge/envs/stable/lib/python3.10/site-packages/pygeos/constructive.py:579: RuntimeWarning: invalid value encountered in polygonize
#   return lib.polygonize(geometries, **kwargs)
#  18%|█▊        | 23/131 [00:14<01:09,  1.55it/s]/Users/martin/mambaforge/envs/stable/lib/python3.10/site-packages/pygeos/constructive.py:579: RuntimeWarning: invalid value encountered in polygonize
#   return lib.polygonize(geometries, **kwargs)
#  18%|█▊        | 24/131 [00:15<01:23,  1.28it/s]/Users/martin/mambaforge/envs/stable/lib/python3.10/site-packages/pygeos/constructive.py:579: RuntimeWarning: invalid value encountered in polygonize
#   return lib.polygonize(geometries, **kwargs)
#  19%|█▉        | 25/131 [00:18<02:45,  1.56s/it]/Users/martin/mambaforge/envs/stable/lib/python3.10/site-packages/pygeos/constructive.py:579: RuntimeWarning: invalid value encountered in polygonize
#   return lib.polygonize(geometries, **kwargs)
#  20%|█▉        | 26/131 [00:22<03:39,  2.09s/it]/Users/martin/mambaforge/envs/stable/lib/python3.10/site-packages/pygeos/constructive.py:579: RuntimeWarning: invalid value encountered in polygonize
#   return lib.polygonize(geometries, **kwargs)
# /Users/martin/mambaforge/envs/stable/lib/python3.10/site-packages/pygeos/constructive.py:478: RuntimeWarning: invalid value encountered in make_valid
#   return lib.make_valid(geometry, **kwargs)
#  21%|██        | 27/131 [00:23<02:59,  1.72s/it]/Users/martin/mambaforge/envs/stable/lib/python3.10/site-packages/pygeos/constructive.py:579: RuntimeWarning: invalid value encountered in polygonize
#   return lib.polygonize(geometries, **kwargs)
#  21%|██▏       | 28/131 [00:23<02:20,  1.37s/it]/Users/martin/mambaforge/envs/stable/lib/python3.10/site-packages/pygeos/constructive.py:579: RuntimeWarning: invalid value encountered in polygonize
#   return lib.polygonize(geometries, **kwargs)
#  22%|██▏       | 29/131 [00:24<01:48,  1.06s/it]/Users/martin/mambaforge/envs/stable/lib/python3.10/site-packages/pygeos/constructive.py:579: RuntimeWarning: invalid value encountered in polygonize
#   return lib.polygonize(geometries, **kwargs)
#  23%|██▎       | 30/131 [00:24<01:25,  1.18it/s]/Users/martin/mambaforge/envs/stable/lib/python3.10/site-packages/pygeos/constructive.py:579: RuntimeWarning: invalid value encountered in polygonize
#   return lib.polygonize(geometries, **kwargs)
#  24%|██▎       | 31/131 [00:25<01:28,  1.13it/s]/Users/martin/mambaforge/envs/stable/lib/python3.10/site-packages/pygeos/constructive.py:579: RuntimeWarning: invalid value encountered in polygonize
#   return lib.polygonize(geometries, **kwargs)
#  24%|██▍       | 32/131 [00:26<01:20,  1.23it/s]/Users/martin/mambaforge/envs/stable/lib/python3.10/site-packages/pygeos/constructive.py:579: RuntimeWarning: invalid value encountered in polygonize
#   return lib.polygonize(geometries, **kwargs)
#  25%|██▌       | 33/131 [00:26<01:06,  1.48it/s]/Users/martin/mambaforge/envs/stable/lib/python3.10/site-packages/pygeos/constructive.py:579: RuntimeWarning: invalid value encountered in polygonize
#   return lib.polygonize(geometries, **kwargs)
#  27%|██▋       | 35/131 [00:27<01:01,  1.57it/s]/Users/martin/mambaforge/envs/stable/lib/python3.10/site-packages/pygeos/constructive.py:579: RuntimeWarning: invalid value encountered in polygonize
#   return lib.polygonize(geometries, **kwargs)
#  27%|██▋       | 36/131 [00:28<01:08,  1.39it/s]/Users/martin/mambaforge/envs/stable/lib/python3.10/site-packages/pygeos/constructive.py:579: RuntimeWarning: invalid value encountered in polygonize
#   return lib.polygonize(geometries, **kwargs)
#  29%|██▉       | 38/131 [00:29<00:47,  1.95it/s]/Users/martin/mambaforge/envs/stable/lib/python3.10/site-packages/pygeos/constructive.py:579: RuntimeWarning: invalid value encountered in polygonize
#   return lib.polygonize(geometries, **kwargs)
#  30%|██▉       | 39/131 [00:30<00:57,  1.60it/s]/Users/martin/mambaforge/envs/stable/lib/python3.10/site-packages/pygeos/constructive.py:579: RuntimeWarning: invalid value encountered in polygonize
#   return lib.polygonize(geometries, **kwargs)
#  31%|███       | 40/131 [00:31<01:13,  1.24it/s]/Users/martin/mambaforge/envs/stable/lib/python3.10/site-packages/pygeos/constructive.py:579: RuntimeWarning: invalid value encountered in polygonize
#   return lib.polygonize(geometries, **kwargs)
#  31%|███▏      | 41/131 [00:31<01:01,  1.46it/s]/Users/martin/mambaforge/envs/stable/lib/python3.10/site-packages/pygeos/constructive.py:579: RuntimeWarning: invalid value encountered in polygonize
#   return lib.polygonize(geometries, **kwargs)
#  33%|███▎      | 43/131 [00:34<01:24,  1.04it/s]/Users/martin/mambaforge/envs/stable/lib/python3.10/site-packages/pygeos/constructive.py:579: RuntimeWarning: invalid value encountered in polygonize
#   return lib.polygonize(geometries, **kwargs)
#  34%|███▎      | 44/131 [00:35<01:14,  1.17it/s]/Users/martin/mambaforge/envs/stable/lib/python3.10/site-packages/pygeos/constructive.py:579: RuntimeWarning: invalid value encountered in polygonize
#   return lib.polygonize(geometries, **kwargs)
#  34%|███▍      | 45/131 [00:35<01:02,  1.38it/s]/Users/martin/mambaforge/envs/stable/lib/python3.10/site-packages/pygeos/constructive.py:579: RuntimeWarning: invalid value encountered in polygonize
#   return lib.polygonize(geometries, **kwargs)
#  35%|███▌      | 46/131 [00:35<00:50,  1.67it/s]/Users/martin/mambaforge/envs/stable/lib/python3.10/site-packages/pygeos/constructive.py:579: RuntimeWarning: invalid value encountered in polygonize
#   return lib.polygonize(geometries, **kwargs)
#  36%|███▌      | 47/131 [00:37<01:03,  1.32it/s]/Users/martin/mambaforge/envs/stable/lib/python3.10/site-packages/pygeos/constructive.py:579: RuntimeWarning: invalid value encountered in polygonize
#   return lib.polygonize(geometries, **kwargs)
#  37%|███▋      | 48/131 [00:37<00:53,  1.54it/s]/Users/martin/mambaforge/envs/stable/lib/python3.10/site-packages/pygeos/constructive.py:579: RuntimeWarning: invalid value encountered in polygonize
#   return lib.polygonize(geometries, **kwargs)
#  38%|███▊      | 50/131 [00:37<00:35,  2.27it/s]/Users/martin/mambaforge/envs/stable/lib/python3.10/site-packages/pygeos/constructive.py:579: RuntimeWarning: invalid value encountered in polygonize
#   return lib.polygonize(geometries, **kwargs)
#  39%|███▉      | 51/131 [00:40<01:17,  1.03it/s]/Users/martin/mambaforge/envs/stable/lib/python3.10/site-packages/pygeos/constructive.py:579: RuntimeWarning: invalid value encountered in polygonize
#   return lib.polygonize(geometries, **kwargs)
# /Users/martin/mambaforge/envs/stable/lib/python3.10/site-packages/pygeos/constructive.py:478: RuntimeWarning: invalid value encountered in make_valid
#   return lib.make_valid(geometry, **kwargs)
#  40%|███▉      | 52/131 [00:40<01:05,  1.21it/s]/Users/martin/mambaforge/envs/stable/lib/python3.10/site-packages/pygeos/constructive.py:579: RuntimeWarning: invalid value encountered in polygonize
#   return lib.polygonize(geometries, **kwargs)
#  40%|████      | 53/131 [00:41<00:59,  1.32it/s]/Users/martin/mambaforge/envs/stable/lib/python3.10/site-packages/pygeos/constructive.py:579: RuntimeWarning: invalid value encountered in polygonize
#   return lib.polygonize(geometries, **kwargs)
#  41%|████      | 54/131 [00:41<00:47,  1.60it/s]/Users/martin/mambaforge/envs/stable/lib/python3.10/site-packages/pygeos/constructive.py:579: RuntimeWarning: invalid value encountered in polygonize
#   return lib.polygonize(geometries, **kwargs)
#  42%|████▏     | 55/131 [00:41<00:37,  2.01it/s]/Users/martin/mambaforge/envs/stable/lib/python3.10/site-packages/pygeos/constructive.py:579: RuntimeWarning: invalid value encountered in polygonize
#   return lib.polygonize(geometries, **kwargs)
#  43%|████▎     | 56/131 [00:42<00:38,  1.93it/s]/Users/martin/mambaforge/envs/stable/lib/python3.10/site-packages/pygeos/constructive.py:579: RuntimeWarning: invalid value encountered in polygonize
#   return lib.polygonize(geometries, **kwargs)
# /Users/martin/mambaforge/envs/stable/lib/python3.10/site-packages/pygeos/constructive.py:478: RuntimeWarning: invalid value encountered in make_valid
#   return lib.make_valid(geometry, **kwargs)
#  44%|████▎     | 57/131 [00:47<02:13,  1.80s/it]/Users/martin/mambaforge/envs/stable/lib/python3.10/site-packages/pygeos/constructive.py:579: RuntimeWarning: invalid value encountered in polygonize
#   return lib.polygonize(geometries, **kwargs)
#  44%|████▍     | 58/131 [00:48<01:53,  1.55s/it]/Users/martin/mambaforge/envs/stable/lib/python3.10/site-packages/pygeos/constructive.py:579: RuntimeWarning: invalid value encountered in polygonize
#   return lib.polygonize(geometries, **kwargs)
#  45%|████▌     | 59/131 [00:48<01:28,  1.23s/it]/Users/martin/mambaforge/envs/stable/lib/python3.10/site-packages/pygeos/constructive.py:579: RuntimeWarning: invalid value encountered in polygonize
#   return lib.polygonize(geometries, **kwargs)
#  46%|████▌     | 60/131 [00:49<01:12,  1.02s/it]/Users/martin/mambaforge/envs/stable/lib/python3.10/site-packages/pygeos/constructive.py:579: RuntimeWarning: invalid value encountered in polygonize
#   return lib.polygonize(geometries, **kwargs)
#  47%|████▋     | 61/131 [00:49<01:05,  1.07it/s]/Users/martin/mambaforge/envs/stable/lib/python3.10/site-packages/pygeos/constructive.py:579: RuntimeWarning: invalid value encountered in polygonize
#   return lib.polygonize(geometries, **kwargs)
#  47%|████▋     | 62/131 [00:50<00:58,  1.18it/s]/Users/martin/mambaforge/envs/stable/lib/python3.10/site-packages/pygeos/constructive.py:579: RuntimeWarning: invalid value encountered in polygonize
#   return lib.polygonize(geometries, **kwargs)
#  48%|████▊     | 63/131 [00:50<00:50,  1.35it/s]/Users/martin/mambaforge/envs/stable/lib/python3.10/site-packages/pygeos/constructive.py:579: RuntimeWarning: invalid value encountered in polygonize
#   return lib.polygonize(geometries, **kwargs)
#  49%|████▉     | 64/131 [00:52<01:02,  1.07it/s]/Users/martin/mambaforge/envs/stable/lib/python3.10/site-packages/pygeos/constructive.py:579: RuntimeWarning: invalid value encountered in polygonize
#   return lib.polygonize(geometries, **kwargs)
#  50%|████▉     | 65/131 [00:52<00:54,  1.21it/s]/Users/martin/mambaforge/envs/stable/lib/python3.10/site-packages/pygeos/constructive.py:579: RuntimeWarning: invalid value encountered in polygonize
#   return lib.polygonize(geometries, **kwargs)
# /Users/martin/mambaforge/envs/stable/lib/python3.10/site-packages/pygeos/constructive.py:478: RuntimeWarning: invalid value encountered in make_valid
#   return lib.make_valid(geometry, **kwargs)
#  50%|█████     | 66/131 [00:54<00:58,  1.12it/s]/Users/martin/mambaforge/envs/stable/lib/python3.10/site-packages/pygeos/constructive.py:579: RuntimeWarning: invalid value encountered in polygonize
#   return lib.polygonize(geometries, **kwargs)
#  51%|█████     | 67/131 [00:54<00:49,  1.29it/s]/Users/martin/mambaforge/envs/stable/lib/python3.10/site-packages/pygeos/constructive.py:579: RuntimeWarning: invalid value encountered in polygonize
#   return lib.polygonize(geometries, **kwargs)
# /Users/martin/mambaforge/envs/stable/lib/python3.10/site-packages/pygeos/constructive.py:478: RuntimeWarning: invalid value encountered in make_valid
#   return lib.make_valid(geometry, **kwargs)
#  52%|█████▏    | 68/131 [00:59<02:12,  2.10s/it]/Users/martin/mambaforge/envs/stable/lib/python3.10/site-packages/pygeos/constructive.py:579: RuntimeWarning: invalid value encountered in polygonize
#   return lib.polygonize(geometries, **kwargs)
#  53%|█████▎    | 69/131 [01:00<01:42,  1.65s/it]/Users/martin/mambaforge/envs/stable/lib/python3.10/site-packages/pygeos/constructive.py:579: RuntimeWarning: invalid value encountered in polygonize
#   return lib.polygonize(geometries, **kwargs)
#  53%|█████▎    | 70/131 [01:00<01:20,  1.32s/it]/Users/martin/mambaforge/envs/stable/lib/python3.10/site-packages/pygeos/constructive.py:579: RuntimeWarning: invalid value encountered in polygonize
#   return lib.polygonize(geometries, **kwargs)
#  54%|█████▍    | 71/131 [01:01<01:08,  1.14s/it]/Users/martin/mambaforge/envs/stable/lib/python3.10/site-packages/pygeos/constructive.py:579: RuntimeWarning: invalid value encountered in polygonize
#   return lib.polygonize(geometries, **kwargs)
#  55%|█████▍    | 72/131 [01:02<00:54,  1.07it/s]/Users/martin/mambaforge/envs/stable/lib/python3.10/site-packages/pygeos/constructive.py:579: RuntimeWarning: invalid value encountered in polygonize
#   return lib.polygonize(geometries, **kwargs)
#  56%|█████▌    | 73/131 [01:02<00:52,  1.10it/s]/Users/martin/mambaforge/envs/stable/lib/python3.10/site-packages/pygeos/constructive.py:579: RuntimeWarning: invalid value encountered in polygonize
#   return lib.polygonize(geometries, **kwargs)
#  56%|█████▋    | 74/131 [01:03<00:44,  1.28it/s]/Users/martin/mambaforge/envs/stable/lib/python3.10/site-packages/pygeos/constructive.py:579: RuntimeWarning: invalid value encountered in polygonize
#   return lib.polygonize(geometries, **kwargs)
# /Users/martin/mambaforge/envs/stable/lib/python3.10/site-packages/pygeos/constructive.py:478: RuntimeWarning: invalid value encountered in make_valid
#   return lib.make_valid(geometry, **kwargs)
#  57%|█████▋    | 75/131 [01:05<01:09,  1.24s/it]/Users/martin/mambaforge/envs/stable/lib/python3.10/site-packages/pygeos/constructive.py:579: RuntimeWarning: invalid value encountered in polygonize
#   return lib.polygonize(geometries, **kwargs)
#  58%|█████▊    | 76/131 [01:07<01:14,  1.35s/it]/Users/martin/mambaforge/envs/stable/lib/python3.10/site-packages/pygeos/constructive.py:579: RuntimeWarning: invalid value encountered in polygonize
#   return lib.polygonize(geometries, **kwargs)
#  59%|█████▉    | 77/131 [01:08<01:08,  1.26s/it]/Users/martin/mambaforge/envs/stable/lib/python3.10/site-packages/pygeos/constructive.py:579: RuntimeWarning: invalid value encountered in polygonize
#   return lib.polygonize(geometries, **kwargs)
#  60%|█████▉    | 78/131 [01:11<01:37,  1.83s/it]/Users/martin/mambaforge/envs/stable/lib/python3.10/site-packages/pygeos/constructive.py:579: RuntimeWarning: invalid value encountered in polygonize
#   return lib.polygonize(geometries, **kwargs)
# /Users/martin/mambaforge/envs/stable/lib/python3.10/site-packages/pygeos/constructive.py:478: RuntimeWarning: invalid value encountered in make_valid
#   return lib.make_valid(geometry, **kwargs)
#  60%|██████    | 79/131 [01:13<01:36,  1.86s/it]/Users/martin/mambaforge/envs/stable/lib/python3.10/site-packages/pygeos/constructive.py:579: RuntimeWarning: invalid value encountered in polygonize
#   return lib.polygonize(geometries, **kwargs)
# /Users/martin/mambaforge/envs/stable/lib/python3.10/site-packages/pygeos/constructive.py:478: RuntimeWarning: invalid value encountered in make_valid
#   return lib.make_valid(geometry, **kwargs)
#  61%|██████    | 80/131 [01:14<01:29,  1.76s/it]/Users/martin/mambaforge/envs/stable/lib/python3.10/site-packages/pygeos/constructive.py:579: RuntimeWarning: invalid value encountered in polygonize
#   return lib.polygonize(geometries, **kwargs)
# /Users/martin/mambaforge/envs/stable/lib/python3.10/site-packages/pygeos/constructive.py:478: RuntimeWarning: invalid value encountered in make_valid
#   return lib.make_valid(geometry, **kwargs)
#  62%|██████▏   | 81/131 [01:15<01:13,  1.47s/it]/Users/martin/mambaforge/envs/stable/lib/python3.10/site-packages/pygeos/constructive.py:579: RuntimeWarning: invalid value encountered in polygonize
#   return lib.polygonize(geometries, **kwargs)
#  63%|██████▎   | 82/131 [01:16<00:59,  1.22s/it]/Users/martin/mambaforge/envs/stable/lib/python3.10/site-packages/pygeos/constructive.py:579: RuntimeWarning: invalid value encountered in polygonize
#   return lib.polygonize(geometries, **kwargs)
# /Users/martin/mambaforge/envs/stable/lib/python3.10/site-packages/pygeos/constructive.py:478: RuntimeWarning: invalid value encountered in make_valid
#   return lib.make_valid(geometry, **kwargs)
#  63%|██████▎   | 83/131 [01:17<00:54,  1.13s/it]/Users/martin/mambaforge/envs/stable/lib/python3.10/site-packages/pygeos/constructive.py:579: RuntimeWarning: invalid value encountered in polygonize
#   return lib.polygonize(geometries, **kwargs)
#  64%|██████▍   | 84/131 [01:18<00:52,  1.12s/it]/Users/martin/mambaforge/envs/stable/lib/python3.10/site-packages/pygeos/constructive.py:579: RuntimeWarning: invalid value encountered in polygonize
#   return lib.polygonize(geometries, **kwargs)
# /Users/martin/mambaforge/envs/stable/lib/python3.10/site-packages/pygeos/constructive.py:478: RuntimeWarning: invalid value encountered in make_valid
#   return lib.make_valid(geometry, **kwargs)
#  65%|██████▍   | 85/131 [01:19<00:57,  1.25s/it]/Users/martin/mambaforge/envs/stable/lib/python3.10/site-packages/pygeos/constructive.py:579: RuntimeWarning: invalid value encountered in polygonize
#   return lib.polygonize(geometries, **kwargs)
# /Users/martin/mambaforge/envs/stable/lib/python3.10/site-packages/pygeos/constructive.py:478: RuntimeWarning: invalid value encountered in make_valid
#   return lib.make_valid(geometry, **kwargs)
#  66%|██████▌   | 86/131 [01:23<01:25,  1.91s/it]/Users/martin/mambaforge/envs/stable/lib/python3.10/site-packages/pygeos/constructive.py:579: RuntimeWarning: invalid value encountered in polygonize
#   return lib.polygonize(geometries, **kwargs)
# /Users/martin/mambaforge/envs/stable/lib/python3.10/site-packages/pygeos/constructive.py:478: RuntimeWarning: invalid value encountered in make_valid
#   return lib.make_valid(geometry, **kwargs)
#  66%|██████▋   | 87/131 [01:27<01:55,  2.62s/it]/Users/martin/mambaforge/envs/stable/lib/python3.10/site-packages/pygeos/constructive.py:579: RuntimeWarning: invalid value encountered in polygonize
#   return lib.polygonize(geometries, **kwargs)
# /Users/martin/mambaforge/envs/stable/lib/python3.10/site-packages/pygeos/constructive.py:478: RuntimeWarning: invalid value encountered in make_valid
#   return lib.make_valid(geometry, **kwargs)
#  67%|██████▋   | 88/131 [01:28<01:29,  2.09s/it]/Users/martin/mambaforge/envs/stable/lib/python3.10/site-packages/pygeos/constructive.py:579: RuntimeWarning: invalid value encountered in polygonize
#   return lib.polygonize(geometries, **kwargs)
# /Users/martin/mambaforge/envs/stable/lib/python3.10/site-packages/pygeos/constructive.py:478: RuntimeWarning: invalid value encountered in make_valid
#   return lib.make_valid(geometry, **kwargs)
#  68%|██████▊   | 89/131 [01:29<01:09,  1.65s/it]/Users/martin/mambaforge/envs/stable/lib/python3.10/site-packages/pygeos/constructive.py:579: RuntimeWarning: invalid value encountered in polygonize
#   return lib.polygonize(geometries, **kwargs)
#  69%|██████▊   | 90/131 [01:29<00:50,  1.23s/it]/Users/martin/mambaforge/envs/stable/lib/python3.10/site-packages/pygeos/constructive.py:579: RuntimeWarning: invalid value encountered in polygonize
#   return lib.polygonize(geometries, **kwargs)
# /Users/martin/mambaforge/envs/stable/lib/python3.10/site-packages/pygeos/constructive.py:478: RuntimeWarning: invalid value encountered in make_valid
#   return lib.make_valid(geometry, **kwargs)
#  69%|██████▉   | 91/131 [01:30<00:44,  1.11s/it]/Users/martin/mambaforge/envs/stable/lib/python3.10/site-packages/pygeos/constructive.py:579: RuntimeWarning: invalid value encountered in polygonize
#   return lib.polygonize(geometries, **kwargs)
#  70%|███████   | 92/131 [01:30<00:38,  1.02it/s]/Users/martin/mambaforge/envs/stable/lib/python3.10/site-packages/pygeos/constructive.py:579: RuntimeWarning: invalid value encountered in polygonize
#   return lib.polygonize(geometries, **kwargs)
#  71%|███████   | 93/131 [01:32<00:49,  1.30s/it]/Users/martin/mambaforge/envs/stable/lib/python3.10/site-packages/pygeos/constructive.py:579: RuntimeWarning: invalid value encountered in polygonize
#   return lib.polygonize(geometries, **kwargs)
#  72%|███████▏  | 94/131 [01:34<00:47,  1.28s/it]/Users/martin/mambaforge/envs/stable/lib/python3.10/site-packages/pygeos/constructive.py:579: RuntimeWarning: invalid value encountered in polygonize
#   return lib.polygonize(geometries, **kwargs)
# /Users/martin/mambaforge/envs/stable/lib/python3.10/site-packages/pygeos/constructive.py:478: RuntimeWarning: invalid value encountered in make_valid
#   return lib.make_valid(geometry, **kwargs)
#  73%|███████▎  | 95/131 [01:34<00:40,  1.12s/it]/Users/martin/mambaforge/envs/stable/lib/python3.10/site-packages/pygeos/constructive.py:579: RuntimeWarning: invalid value encountered in polygonize
#   return lib.polygonize(geometries, **kwargs)
# /Users/martin/mambaforge/envs/stable/lib/python3.10/site-packages/pygeos/constructive.py:478: RuntimeWarning: invalid value encountered in make_valid
#   return lib.make_valid(geometry, **kwargs)
#  73%|███████▎  | 96/131 [01:35<00:34,  1.01it/s]/Users/martin/mambaforge/envs/stable/lib/python3.10/site-packages/pygeos/constructive.py:579: RuntimeWarning: invalid value encountered in polygonize
#   return lib.polygonize(geometries, **kwargs)
#  74%|███████▍  | 97/131 [01:35<00:25,  1.33it/s]/Users/martin/mambaforge/envs/stable/lib/python3.10/site-packages/pygeos/constructive.py:579: RuntimeWarning: invalid value encountered in polygonize
#   return lib.polygonize(geometries, **kwargs)
# /Users/martin/mambaforge/envs/stable/lib/python3.10/site-packages/pygeos/constructive.py:478: RuntimeWarning: invalid value encountered in make_valid
#   return lib.make_valid(geometry, **kwargs)
#  75%|███████▍  | 98/131 [01:36<00:28,  1.17it/s]/Users/martin/mambaforge/envs/stable/lib/python3.10/site-packages/pygeos/constructive.py:579: RuntimeWarning: invalid value encountered in polygonize
#   return lib.polygonize(geometries, **kwargs)
# /Users/martin/mambaforge/envs/stable/lib/python3.10/site-packages/pygeos/constructive.py:478: RuntimeWarning: invalid value encountered in make_valid
#   return lib.make_valid(geometry, **kwargs)
#  76%|███████▌  | 99/131 [01:38<00:34,  1.09s/it]/Users/martin/mambaforge/envs/stable/lib/python3.10/site-packages/pygeos/constructive.py:579: RuntimeWarning: invalid value encountered in polygonize
#   return lib.polygonize(geometries, **kwargs)
# /Users/martin/mambaforge/envs/stable/lib/python3.10/site-packages/pygeos/constructive.py:478: RuntimeWarning: invalid value encountered in make_valid
#   return lib.make_valid(geometry, **kwargs)
#  76%|███████▋  | 100/131 [01:39<00:32,  1.04s/it]/Users/martin/mambaforge/envs/stable/lib/python3.10/site-packages/pygeos/constructive.py:579: RuntimeWarning: invalid value encountered in polygonize
#   return lib.polygonize(geometries, **kwargs)
#  77%|███████▋  | 101/131 [01:39<00:25,  1.18it/s]/Users/martin/mambaforge/envs/stable/lib/python3.10/site-packages/pygeos/constructive.py:579: RuntimeWarning: invalid value encountered in polygonize
#   return lib.polygonize(geometries, **kwargs)
# /Users/martin/mambaforge/envs/stable/lib/python3.10/site-packages/pygeos/constructive.py:478: RuntimeWarning: invalid value encountered in make_valid
#   return lib.make_valid(geometry, **kwargs)
#  78%|███████▊  | 102/131 [01:41<00:29,  1.01s/it]/Users/martin/mambaforge/envs/stable/lib/python3.10/site-packages/pygeos/constructive.py:579: RuntimeWarning: invalid value encountered in polygonize
#   return lib.polygonize(geometries, **kwargs)
# /Users/martin/mambaforge/envs/stable/lib/python3.10/site-packages/pygeos/constructive.py:478: RuntimeWarning: invalid value encountered in make_valid
#   return lib.make_valid(geometry, **kwargs)
#  79%|███████▊  | 103/131 [01:42<00:33,  1.21s/it]/Users/martin/mambaforge/envs/stable/lib/python3.10/site-packages/pygeos/constructive.py:579: RuntimeWarning: invalid value encountered in polygonize
#   return lib.polygonize(geometries, **kwargs)
#  79%|███████▉  | 104/131 [01:43<00:27,  1.01s/it]/Users/martin/mambaforge/envs/stable/lib/python3.10/site-packages/pygeos/constructive.py:579: RuntimeWarning: invalid value encountered in polygonize
#   return lib.polygonize(geometries, **kwargs)
# /Users/martin/mambaforge/envs/stable/lib/python3.10/site-packages/pygeos/constructive.py:478: RuntimeWarning: invalid value encountered in make_valid
#   return lib.make_valid(geometry, **kwargs)
#  80%|████████  | 105/131 [01:43<00:21,  1.20it/s]/Users/martin/mambaforge/envs/stable/lib/python3.10/site-packages/pygeos/constructive.py:579: RuntimeWarning: invalid value encountered in polygonize
#   return lib.polygonize(geometries, **kwargs)
#  81%|████████  | 106/131 [01:44<00:16,  1.54it/s]/Users/martin/mambaforge/envs/stable/lib/python3.10/site-packages/pygeos/constructive.py:579: RuntimeWarning: invalid value encountered in polygonize
#   return lib.polygonize(geometries, **kwargs)
#  82%|████████▏ | 107/131 [01:44<00:14,  1.62it/s]/Users/martin/mambaforge/envs/stable/lib/python3.10/site-packages/pygeos/constructive.py:579: RuntimeWarning: invalid value encountered in polygonize
#   return lib.polygonize(geometries, **kwargs)
# /Users/martin/mambaforge/envs/stable/lib/python3.10/site-packages/pygeos/constructive.py:478: RuntimeWarning: invalid value encountered in make_valid
#   return lib.make_valid(geometry, **kwargs)
#  82%|████████▏ | 108/131 [01:45<00:16,  1.44it/s]/Users/martin/mambaforge/envs/stable/lib/python3.10/site-packages/pygeos/constructive.py:579: RuntimeWarning: invalid value encountered in polygonize
#   return lib.polygonize(geometries, **kwargs)
#  83%|████████▎ | 109/131 [01:46<00:16,  1.30it/s]/Users/martin/mambaforge/envs/stable/lib/python3.10/site-packages/pygeos/constructive.py:579: RuntimeWarning: invalid value encountered in polygonize
#   return lib.polygonize(geometries, **kwargs)
# /Users/martin/mambaforge/envs/stable/lib/python3.10/site-packages/pygeos/constructive.py:478: RuntimeWarning: invalid value encountered in make_valid
#   return lib.make_valid(geometry, **kwargs)
#  84%|████████▍ | 110/131 [01:49<00:29,  1.39s/it]/Users/martin/mambaforge/envs/stable/lib/python3.10/site-packages/pygeos/constructive.py:579: RuntimeWarning: invalid value encountered in polygonize
#   return lib.polygonize(geometries, **kwargs)
#  85%|████████▍ | 111/131 [01:50<00:24,  1.21s/it]/Users/martin/mambaforge/envs/stable/lib/python3.10/site-packages/pygeos/constructive.py:579: RuntimeWarning: invalid value encountered in polygonize
#   return lib.polygonize(geometries, **kwargs)
#  85%|████████▌ | 112/131 [01:50<00:18,  1.05it/s]/Users/martin/mambaforge/envs/stable/lib/python3.10/site-packages/pygeos/constructive.py:579: RuntimeWarning: invalid value encountered in polygonize
#   return lib.polygonize(geometries, **kwargs)
# /Users/martin/mambaforge/envs/stable/lib/python3.10/site-packages/pygeos/constructive.py:478: RuntimeWarning: invalid value encountered in make_valid
#   return lib.make_valid(geometry, **kwargs)
#  86%|████████▋ | 113/131 [01:51<00:16,  1.08it/s]/Users/martin/mambaforge/envs/stable/lib/python3.10/site-packages/pygeos/constructive.py:579: RuntimeWarning: invalid value encountered in polygonize
#   return lib.polygonize(geometries, **kwargs)
# /Users/martin/mambaforge/envs/stable/lib/python3.10/site-packages/pygeos/constructive.py:478: RuntimeWarning: invalid value encountered in make_valid
#   return lib.make_valid(geometry, **kwargs)
#  87%|████████▋ | 114/131 [01:55<00:32,  1.92s/it]/Users/martin/mambaforge/envs/stable/lib/python3.10/site-packages/pygeos/constructive.py:579: RuntimeWarning: invalid value encountered in polygonize
#   return lib.polygonize(geometries, **kwargs)
#  88%|████████▊ | 115/131 [01:56<00:25,  1.59s/it]/Users/martin/mambaforge/envs/stable/lib/python3.10/site-packages/pygeos/constructive.py:579: RuntimeWarning: invalid value encountered in polygonize
#   return lib.polygonize(geometries, **kwargs)
#  89%|████████▊ | 116/131 [01:56<00:17,  1.20s/it]/Users/martin/mambaforge/envs/stable/lib/python3.10/site-packages/pygeos/constructive.py:579: RuntimeWarning: invalid value encountered in polygonize
#   return lib.polygonize(geometries, **kwargs)
# /Users/martin/mambaforge/envs/stable/lib/python3.10/site-packages/pygeos/constructive.py:478: RuntimeWarning: invalid value encountered in make_valid
#   return lib.make_valid(geometry, **kwargs)
#  89%|████████▉ | 117/131 [01:59<00:23,  1.66s/it]/Users/martin/mambaforge/envs/stable/lib/python3.10/site-packages/pygeos/constructive.py:579: RuntimeWarning: invalid value encountered in polygonize
#   return lib.polygonize(geometries, **kwargs)
# /Users/martin/mambaforge/envs/stable/lib/python3.10/site-packages/pygeos/constructive.py:478: RuntimeWarning: invalid value encountered in make_valid
#   return lib.make_valid(geometry, **kwargs)
#  90%|█████████ | 118/131 [02:05<00:39,  3.06s/it]/Users/martin/mambaforge/envs/stable/lib/python3.10/site-packages/pygeos/constructive.py:579: RuntimeWarning: invalid value encountered in polygonize
#   return lib.polygonize(geometries, **kwargs)
# /Users/martin/mambaforge/envs/stable/lib/python3.10/site-packages/pygeos/constructive.py:478: RuntimeWarning: invalid value encountered in make_valid
#   return lib.make_valid(geometry, **kwargs)
#  91%|█████████ | 119/131 [02:09<00:39,  3.33s/it]/Users/martin/mambaforge/envs/stable/lib/python3.10/site-packages/pygeos/constructive.py:579: RuntimeWarning: invalid value encountered in polygonize
#   return lib.polygonize(geometries, **kwargs)
# /Users/martin/mambaforge/envs/stable/lib/python3.10/site-packages/pygeos/constructive.py:478: RuntimeWarning: invalid value encountered in make_valid
#   return lib.make_valid(geometry, **kwargs)
#  92%|█████████▏| 120/131 [02:11<00:32,  2.95s/it]/Users/martin/mambaforge/envs/stable/lib/python3.10/site-packages/pygeos/constructive.py:579: RuntimeWarning: invalid value encountered in polygonize
#   return lib.polygonize(geometries, **kwargs)
#  92%|█████████▏| 121/131 [02:13<00:25,  2.52s/it]/Users/martin/mambaforge/envs/stable/lib/python3.10/site-packages/pygeos/constructive.py:579: RuntimeWarning: invalid value encountered in polygonize
#   return lib.polygonize(geometries, **kwargs)
# /Users/martin/mambaforge/envs/stable/lib/python3.10/site-packages/pygeos/constructive.py:478: RuntimeWarning: invalid value encountered in make_valid
#   return lib.make_valid(geometry, **kwargs)
#  93%|█████████▎| 122/131 [02:21<00:38,  4.31s/it]/Users/martin/mambaforge/envs/stable/lib/python3.10/site-packages/pygeos/constructive.py:579: RuntimeWarning: invalid value encountered in polygonize
#   return lib.polygonize(geometries, **kwargs)
# /Users/martin/mambaforge/envs/stable/lib/python3.10/site-packages/pygeos/constructive.py:478: RuntimeWarning: invalid value encountered in make_valid
#   return lib.make_valid(geometry, **kwargs)
#  94%|█████████▍| 123/131 [02:27<00:37,  4.64s/it]/Users/martin/mambaforge/envs/stable/lib/python3.10/site-packages/pygeos/constructive.py:579: RuntimeWarning: invalid value encountered in polygonize
#   return lib.polygonize(geometries, **kwargs)
# /Users/martin/mambaforge/envs/stable/lib/python3.10/site-packages/pygeos/constructive.py:478: RuntimeWarning: invalid value encountered in make_valid
#   return lib.make_valid(geometry, **kwargs)
#  95%|█████████▍| 124/131 [02:29<00:26,  3.82s/it]/Users/martin/mambaforge/envs/stable/lib/python3.10/site-packages/pygeos/constructive.py:579: RuntimeWarning: invalid value encountered in polygonize
#   return lib.polygonize(geometries, **kwargs)
# /Users/martin/mambaforge/envs/stable/lib/python3.10/site-packages/pygeos/constructive.py:478: RuntimeWarning: invalid value encountered in make_valid
#   return lib.make_valid(geometry, **kwargs)
#  95%|█████████▌| 125/131 [02:31<00:20,  3.45s/it]/Users/martin/mambaforge/envs/stable/lib/python3.10/site-packages/pygeos/constructive.py:579: RuntimeWarning: invalid value encountered in polygonize
#   return lib.polygonize(geometries, **kwargs)
#  96%|█████████▌| 126/131 [02:32<00:13,  2.66s/it]/Users/martin/mambaforge/envs/stable/lib/python3.10/site-packages/pygeos/constructive.py:579: RuntimeWarning: invalid value encountered in polygonize
#   return lib.polygonize(geometries, **kwargs)
#  97%|█████████▋| 127/131 [02:32<00:08,  2.02s/it]/Users/martin/mambaforge/envs/stable/lib/python3.10/site-packages/pygeos/constructive.py:579: RuntimeWarning: invalid value encountered in polygonize
#   return lib.polygonize(geometries, **kwargs)
# /Users/martin/mambaforge/envs/stable/lib/python3.10/site-packages/pygeos/constructive.py:478: RuntimeWarning: invalid value encountered in make_valid
#   return lib.make_valid(geometry, **kwargs)
#  98%|█████████▊| 128/131 [02:34<00:05,  1.90s/it]/Users/martin/mambaforge/envs/stable/lib/python3.10/site-packages/pygeos/constructive.py:579: RuntimeWarning: invalid value encountered in polygonize
#   return lib.polygonize(geometries, **kwargs)
# /Users/martin/mambaforge/envs/stable/lib/python3.10/site-packages/pygeos/constructive.py:478: RuntimeWarning: invalid value encountered in make_valid
#   return lib.make_valid(geometry, **kwargs)
#  98%|█████████▊| 129/131 [02:36<00:03,  1.99s/it]/Users/martin/mambaforge/envs/stable/lib/python3.10/site-packages/pygeos/constructive.py:579: RuntimeWarning: invalid value encountered in polygonize
#   return lib.polygonize(geometries, **kwargs)
# /Users/martin/mambaforge/envs/stable/lib/python3.10/site-packages/pygeos/constructive.py:478: RuntimeWarning: invalid value encountered in make_valid
#   return lib.make_valid(geometry, **kwargs)
#  99%|█████████▉| 130/131 [02:39<00:02,  2.05s/it]/Users/martin/mambaforge/envs/stable/lib/python3.10/site-packages/pygeos/constructive.py:579: RuntimeWarning: invalid value encountered in polygonize
#   return lib.polygonize(geometries, **kwargs)
# /Users/martin/mambaforge/envs/stable/lib/python3.10/site-packages/pygeos/constructive.py:478: RuntimeWarning: invalid value encountered in make_valid
#   return lib.make_valid(geometry, **kwargs)
# 100%|██████████| 131/131 [02:40<00:00,  1.23s/it]
