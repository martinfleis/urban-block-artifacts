# %% [markdown]
# # Geographical differences
#
# Plot figures unpacking the differences in $\phi$ and $T$ across different regions.

# %%
import string
import json

import geopandas
import pandas
import numpy
import matplotlib.pyplot as plt
from matplotlib import rcParams
import seaborn as sns
from palettable.cartocolors.qualitative import Bold_6

from scipy.signal import find_peaks
from scipy.stats import gaussian_kde

# %% [markdown]
# Set default plotting theme and add color dictionary for continents.

# %%
sns.set_theme(
    context="paper",
    style="ticks",
    rc={
        "patch.force_edgecolor": False,
        "axes.spines.top": False,
        "axes.spines.right": False,
        "axes.grid": True,
    },
    palette=Bold_6.hex_colors,
)

coldict = {
    "Africa": 0,
    "Asia": 1,
    "Europe": 2,
    "North America": 3,
    "Oceania": 4,
    "South America": 5,
}

# %%
results = json.load(open("../results/04_peaks_results.json"))

# %% [markdown]
# Load the cities / urban blocks data and combine them to a single GeoDataFrame.

# %%
sample = geopandas.read_parquet("../data/sample.parquet")

# %%
continents = sample.set_index("eFUA_name").continent

# %%
cont = "Asia"
cities = continents[continents == cont].index

fig, ax = plt.subplots(
    figsize=(5, 4),
    sharex=True,
    sharey=True,
    layout="constrained",
)
for city in cities:
    # get continent color from dict
    continent = continents[city]
    continent_color = sns.color_palette(n_colors=6)[coldict[cont]]

    my_pdf = numpy.array(results[city]["circular_compactness_index"]["pdf"])

    mylinspace = numpy.linspace(
        start=results[city]["circular_compactness_index"]["linspace_params"]["start"],
        stop=results[city]["circular_compactness_index"]["linspace_params"]["stop"],
        num=results[city]["circular_compactness_index"]["linspace_params"]["num"],
    )

    ax.plot(
        mylinspace,
        my_pdf,
        color=continent_color,
        zorder=0,
        linewidth=0.2,
    )

    ax.vlines(
        x=mylinspace[results[city]["circular_compactness_index"]["valleys"]],
        ymin=0,
        ymax=0.1,
        color="red",
        # linestyles="dotted",
        alpha=1,
        linewidth=0.1,
    )


ax.set_xlim([-5, 20])
ax.set_ylim([0, 1])
# Out:
# (0.0, 1.0)

# %%
cont = "Africa"
cities = continents[continents == cont].index

fig, ax = plt.subplots(
    figsize=(5, 4),
    sharex=True,
    sharey=True,
    layout="constrained",
)
for city in cities:
    # get continent color from dict
    continent = continents[city]
    continent_color = sns.color_palette(n_colors=6)[coldict[cont]]

    my_pdf = numpy.array(results[city]["circular_compactness_index"]["pdf"])

    mylinspace = numpy.linspace(
        start=results[city]["circular_compactness_index"]["linspace_params"]["start"],
        stop=results[city]["circular_compactness_index"]["linspace_params"]["stop"],
        num=results[city]["circular_compactness_index"]["linspace_params"]["num"],
    )

    ax.plot(
        mylinspace,
        my_pdf,
        color=continent_color,
        zorder=0,
        linewidth=0.2,
    )

    ax.vlines(
        x=mylinspace[results[city]["circular_compactness_index"]["valleys"]],
        ymin=0,
        ymax=0.1,
        color="red",
        # linestyles="dotted",
        alpha=1,
        linewidth=0.1,
    )


ax.set_xlim([-5, 20])
ax.set_ylim([0, 1])
# Out:
# (0.0, 1.0)

# %%
cont = "South America"
cities = continents[continents == cont].index

fig, ax = plt.subplots(
    figsize=(5, 4),
    sharex=True,
    sharey=True,
    layout="constrained",
)

for city in cities:
    # get continent color from dict
    continent = continents[city]
    continent_color = sns.color_palette(n_colors=6)[coldict[cont]]

    my_pdf = numpy.array(results[city]["circular_compactness_index"]["pdf"])

    mylinspace = numpy.linspace(
        start=results[city]["circular_compactness_index"]["linspace_params"]["start"],
        stop=results[city]["circular_compactness_index"]["linspace_params"]["stop"],
        num=results[city]["circular_compactness_index"]["linspace_params"]["num"],
    )

    ax.plot(
        mylinspace,
        my_pdf,
        color=continent_color,
        zorder=0,
        linewidth=0.2,
    )

    ax.vlines(
        x=mylinspace[results[city]["circular_compactness_index"]["valleys"]],
        ymin=0,
        ymax=0.1,
        color="red",
        # linestyles="dotted",
        alpha=1,
        linewidth=0.1,
    )


ax.set_xlim([-5, 20])
ax.set_ylim([0, 1])
# Out:
# (0.0, 1.0)

# %%
cont = "Oceania"
cities = continents[continents == cont].index

fig, ax = plt.subplots(
    figsize=(5, 4),
    sharex=True,
    sharey=True,
    layout="constrained",
)
for city in cities:
    # get continent color from dict
    continent = continents[city]
    continent_color = sns.color_palette(n_colors=6)[coldict[cont]]

    my_pdf = numpy.array(results[city]["circular_compactness_index"]["pdf"])

    mylinspace = numpy.linspace(
        start=results[city]["circular_compactness_index"]["linspace_params"]["start"],
        stop=results[city]["circular_compactness_index"]["linspace_params"]["stop"],
        num=results[city]["circular_compactness_index"]["linspace_params"]["num"],
    )

    ax.plot(
        mylinspace,
        my_pdf,
        color=continent_color,
        zorder=0,
        linewidth=0.2,
    )

    ax.vlines(
        x=mylinspace[results[city]["circular_compactness_index"]["valleys"]],
        ymin=0,
        ymax=0.1,
        color="red",
        # linestyles="dotted",
        alpha=1,
        linewidth=0.1,
    )


ax.set_xlim([-5, 20])
ax.set_ylim([0, 1])
# Out:
# (0.0, 1.0)

# %%
cont = "Europe"
cities = continents[continents == cont].index

fig, ax = plt.subplots(
    figsize=(5, 4),
    sharex=True,
    sharey=True,
    layout="constrained",
)
for city in cities:
    # get continent color from dict
    continent = continents[city]
    continent_color = sns.color_palette(n_colors=6)[coldict[cont]]

    my_pdf = numpy.array(results[city]["circular_compactness_index"]["pdf"])

    mylinspace = numpy.linspace(
        start=results[city]["circular_compactness_index"]["linspace_params"]["start"],
        stop=results[city]["circular_compactness_index"]["linspace_params"]["stop"],
        num=results[city]["circular_compactness_index"]["linspace_params"]["num"],
    )

    ax.plot(
        mylinspace,
        my_pdf,
        color=continent_color,
        zorder=0,
        linewidth=0.2,
    )

    ax.vlines(
        x=mylinspace[results[city]["circular_compactness_index"]["valleys"]],
        ymin=0,
        ymax=0.1,
        color="red",
        # linestyles="dotted",
        alpha=1,
        linewidth=0.1,
    )


ax.set_xlim([-5, 20])
ax.set_ylim([0, 1])
# Out:
# (0.0, 1.0)

# %%
cont = "North America"
cities = continents[continents == cont].index

fig, ax = plt.subplots(
    figsize=(5, 4),
    sharex=True,
    sharey=True,
    layout="constrained",
)
for city in cities:
    # get continent color from dict
    continent = continents[city]
    continent_color = sns.color_palette(n_colors=6)[coldict[cont]]

    my_pdf = numpy.array(results[city]["circular_compactness_index"]["pdf"])

    mylinspace = numpy.linspace(
        start=results[city]["circular_compactness_index"]["linspace_params"]["start"],
        stop=results[city]["circular_compactness_index"]["linspace_params"]["stop"],
        num=results[city]["circular_compactness_index"]["linspace_params"]["num"],
    )

    ax.plot(
        mylinspace,
        my_pdf,
        color=continent_color,
        zorder=0,
        linewidth=0.2,
    )

    ax.vlines(
        x=mylinspace[results[city]["circular_compactness_index"]["valleys"]],
        ymin=0,
        ymax=0.1,
        color="red",
        # linestyles="dotted",
        alpha=1,
        linewidth=0.1,
    )


ax.set_xlim([-5, 20])
ax.set_ylim([0, 1])
# Out:
# (0.0, 1.0)

# %%
fig, ax = plt.subplots(
    figsize=(5, 4),
    sharex=True,
    sharey=True,
    layout="constrained",
)
for city in continents.index:
    # get continent color from dict
    continent = continents[city]
    continent_color = sns.color_palette(n_colors=6)[coldict[continent]]

    my_pdf = numpy.array(results[city]["circular_compactness_index"]["pdf"])

    mylinspace = numpy.linspace(
        start=results[city]["circular_compactness_index"]["linspace_params"]["start"],
        stop=results[city]["circular_compactness_index"]["linspace_params"]["stop"],
        num=results[city]["circular_compactness_index"]["linspace_params"]["num"],
    )

    ax.plot(
        mylinspace,
        my_pdf,
        color=continent_color,
        zorder=0,
        linewidth=0.1,
    )

    ax.vlines(
        x=mylinspace[results[city]["circular_compactness_index"]["valleys"]],
        ymin=0,
        ymax=0.1,
        color="red",
        # linestyles="dotted",
        alpha=1,
        linewidth=0.1,
    )


ax.set_xlim([0, 17])
ax.set_ylim([0, 1])
# Out:
# (0.0, 1.0)

# %%
fig, ax = plt.subplots(
    figsize=(5, 4),
    sharex=True,
    sharey=True,
    layout="constrained",
)
for city in continents.index:
    # get continent color from dict
    continent = continents[city]
    continent_color = sns.color_palette(n_colors=6)[coldict[continent]]

    mylinspace = numpy.linspace(
        start=results[city]["circular_compactness_index"]["linspace_params"]["start"],
        stop=results[city]["circular_compactness_index"]["linspace_params"]["stop"],
        num=results[city]["circular_compactness_index"]["linspace_params"]["num"],
    )

    ax.vlines(
        x=mylinspace[results[city]["circular_compactness_index"]["peaks"]],
        ymin=0,
        ymax=1,
        color=continent_color,
        # linestyles="dotted",
        alpha=1,
        linewidth=0.2,
    )


ax.set_xlim([0, 17])
ax.set_ylim([0, 1])
# Out:
# (0.0, 1.0)

# %%
fig, ax = plt.subplots(
    figsize=(5, 4),
    sharex=True,
    sharey=True,
    layout="constrained",
)
for city in continents.index:
    # get continent color from dict
    continent = continents[city]
    continent_color = sns.color_palette(n_colors=6)[coldict[continent]]

    mylinspace = numpy.linspace(
        start=results[city]["circular_compactness_index"]["linspace_params"]["start"],
        stop=results[city]["circular_compactness_index"]["linspace_params"]["stop"],
        num=results[city]["circular_compactness_index"]["linspace_params"]["num"],
    )

    ax.vlines(
        x=mylinspace[results[city]["circular_compactness_index"]["valleys"]],
        ymin=0,
        ymax=1,
        color=continent_color,
        # linestyles="dotted",
        alpha=1,
        linewidth=0.2,
    )


ax.set_xlim([0, 17])
ax.set_ylim([0, 1])
# Out:
# (0.0, 1.0)

# %%
combined_resuts = pandas.DataFrame(columns=["continent", "peaks", "valleys"])
for city in continents.index:
    mylinspace = numpy.linspace(
        start=results[city]["circular_compactness_index"]["linspace_params"]["start"],
        stop=results[city]["circular_compactness_index"]["linspace_params"]["stop"],
        num=results[city]["circular_compactness_index"]["linspace_params"]["num"],
    )
    combined_resuts.loc[city] = [
        continents[city],
        mylinspace[results[city]["circular_compactness_index"]["peaks"]],
        mylinspace[results[city]["circular_compactness_index"]["valleys"]],
    ]

# %%
peaks = combined_resuts.explode("valleys").drop(columns="peaks")

# %%
sns.boxplot(
    peaks,
    x="continent",
    y="valleys",
    showfliers=False,
)
# Out:
# <AxesSubplot: xlabel='continent', ylabel='valleys'>

# %%
sns.stripplot(
    peaks.reset_index(drop=True), x="continent", y="valleys", hue="continent", s=3
)
# Out:
# <AxesSubplot: xlabel='continent', ylabel='valleys'>

# %%
fig, axs = plt.subplot_mosaic(
    [
        continents.unique().tolist(),
        ["combined", "combined", "combined", "box", "box", "box"],
        ["combined", "combined", "combined", "box", "box", "box"],
        ["combined", "combined", "combined", "box", "box", "box"],
    ],
    figsize=(10, 4),
)
for i, cont in enumerate(continents.unique()):
    cities = continents[continents == cont].index

    ax = axs[cont]

    for city in cities:
        # get continent color from dict
        continent = continents[city]
        continent_color = sns.color_palette(n_colors=6)[coldict[cont]]

        my_pdf = numpy.array(results[city]["circular_compactness_index"]["pdf"])

        mylinspace = numpy.linspace(
            start=results[city]["circular_compactness_index"]["linspace_params"][
                "start"
            ],
            stop=results[city]["circular_compactness_index"]["linspace_params"]["stop"],
            num=results[city]["circular_compactness_index"]["linspace_params"]["num"],
        )

        ax.plot(
            mylinspace,
            my_pdf,
            color=continent_color,
            zorder=0,
            linewidth=0.2,
        )
        ax.vlines(
            x=mylinspace[results[city]["circular_compactness_index"]["valleys"]],
            ymin=0.9,
            ymax=1,
            color="red",
            # linestyles="dotted",
            alpha=1,
            linewidth=0.1,
        )

    ax.set_xlim([0, 17])
    ax.set_ylim([0, 1])
    if cont == continents.unique()[0]:
        ax.tick_params(
            axis="both",
            which="both",
            bottom=False,
            left=True,
            labelbottom=False,
            labelleft=True,
        )
    else:
        ax.tick_params(
            axis="both",
            which="both",
            bottom=False,
            left=True,
            labelbottom=False,
            labelleft=False,
        )
    ax.grid(False)
    ax.set_title(
        cont[:8] + "." if len(cont) > 8 else cont,
        fontdict={"fontsize": rcParams["ytick.labelsize"]},
    )
    ax.text(.99, .99, f"{string.ascii_lowercase[i]})", horizontalalignment='right',
        verticalalignment='top', transform=ax.transAxes)

for city in continents.index:
    # get continent color from dict
    continent = continents[city]
    continent_color = sns.color_palette(n_colors=6)[coldict[continent]]

    my_pdf = numpy.array(results[city]["circular_compactness_index"]["pdf"])

    mylinspace = numpy.linspace(
        start=results[city]["circular_compactness_index"]["linspace_params"]["start"],
        stop=results[city]["circular_compactness_index"]["linspace_params"]["stop"],
        num=results[city]["circular_compactness_index"]["linspace_params"]["num"],
    )

    axs["combined"].plot(
        mylinspace,
        my_pdf,
        color=continent_color,
        zorder=0,
        linewidth=0.15,
    )
    axs["combined"].vlines(
        x=mylinspace[results[city]["circular_compactness_index"]["valleys"]],
        ymin=0.9,
        ymax=1,
        color="red",
        # linestyles="dotted",
        alpha=1,
        linewidth=0.1,
    )


axs["combined"].set_xlim(0, 17)
axs["combined"].set_ylim(0, 1)

sns.boxplot(
    peaks,
    y="continent",
    x="valleys",
    showfliers=False,
    ax=axs["box"],
    boxprops={"facecolor": "none"},
    linewidth=0.7,
)
sns.stripplot(
    peaks.reset_index(drop=True),
    y="continent",
    x="valleys",
    hue="continent",
    s=3,
    ax=axs["box"],
    legend=False,
    palette={c: Bold_6.hex_colors[v] for c, v in coldict.items()},
    alpha=0.75,
)
axs["box"].yaxis.tick_right()
axs["box"].set_xlim(4.5, 8.6)
sns.despine(ax=axs["box"], top=True, left=True, right=False)
axs["box"].tick_params(axis="y", which="both", right=True)

axs["Asia"].set_ylabel(r"$\phi_{i}$")
axs["combined"].set_ylabel(r"Probability density $\phi_{i}$")
axs["combined"].set_xlabel("$F_{cc}$")
axs["box"].set_ylabel("")
axs["box"].set_xlabel("$T$ of $F_{cc}$")

axs["combined"].annotate(
    "$T$",
    xy=(1, 0.94),
    xytext=(-0.6, 0.925),

)

# Add subplot labels

axs["combined"].text(.99, .99, "g)", horizontalalignment='right',
        verticalalignment='top', transform=axs["combined"].transAxes)

axs["box"].text(.99, .99, "h)", horizontalalignment='right',
        verticalalignment='top', transform=axs["box"].transAxes)


plt.savefig("../plots/peaks/geog_differences.png", dpi=600, bbox_inches="tight")
